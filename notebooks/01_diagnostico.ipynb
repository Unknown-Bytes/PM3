# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

arquivo = '../dados_brutos/netflix_raw.csv'

df = pd.read_csv(arquivo)

df.head()

df.info()

df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8820 non-null   str
#  1   type          8819 non-null   str
#  2   title         8820 non-null   str
#  3   director      7940 non-null   str
#  4   country       7944 non-null   str
#  5   date_added    7921 non-null   str
#  6   release_year  8820 non-null   str
#  7   rating        7918 non-null   str
#  8   duration      8820 non-null   str
#  9   listed_in     8820 non-null   str
# dtypes: str(10)
# memory usage: 689.2 KB
#        show_id   type  title   director        country date_added  \
# count     8820   8819   8820       7940           7944       7921
# unique    8790      8   8818       3966             87       1642
# top      s6865  Movie  9-Feb  Not Given  United States        ???
# freq         2   6132      2       2210           2760        214
#
# ...
